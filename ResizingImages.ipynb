# %%
#1. Upload Your Images to Colab
from google.colab import drive
drive.mount('/content/drive')

# %%
#Resizing Images
import cv2
import os

input_folder = '/content/drive/MyDrive/path/to/your/images/'
output_folder = '/content/drive/MyDrive/path/to/your/resized_images/'
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        img_path = os.path.join(input_folder, filename)
        img = cv2.imread(img_path)
        img_resized = cv2.resize(img, (256, 256), interpolation=cv2.INTER_AREA)
        cv2.imwrite(os.path.join(output_folder, filename), img_resized)
